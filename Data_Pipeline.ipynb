# %%
import configparser
from datetime import datetime
import os
import json
from pyspark.sql import SparkSession
from pyspark.sql import Row
import pyspark.sql.functions as F
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format, dayofweek, monotonically_increasing_id, row_number
from pyspark.sql.window import Window
from datetime import datetime

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')

os.environ['AWS_ACCESS_KEY_ID'] = config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY'] = config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
def create_spark_session():
    spark = SparkSession \
        .builder \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
        .getOrCreate()
    return spark

# %%
spark = create_spark_session()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://hongyu:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.3.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
input_data = "s3a://udacity-dend/"
output_data = ""

# %%
log_rdd = sc.textFile(input_data + 'log_data/*/*').map(lambda x: json.loads(x))
log_df = log_rdd.map(lambda items: Row(**items)).toDF()
log_df.printSchema()
log_df.limit(3).toPandas()
log_df.cache()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
# DataFrame[artist: string, auth: string, firstName: string, gender: string, itemInSession: bigint, lastName: string, length: double, level: string, location: string, method: string, page: string, registration: double, sessionId: bigint, song: string, status: bigint, ts: bigint, userAgent: string, userId: string]

# %%
# songSchema = R([
#     Fld('num_songs', Int()),
#     Fld('artist_id', Str()),
#     Fld('artist_latitude', Dbl()),
#     Fld('artist_longitude', Dbl()),
#     Fld('artist_location', Str()),
#     Fld('artist_name', Str()),
#     Fld('song_id', Str()),
#     Fld('title', Str()),
#     Fld('duration', Dbl()),
#     Fld('year', Int())
# ])

# %%
# subdir = [x[0] for x in os.walk(song_data)]
# song_df = spark.read.json(subdir, schema=songSchema)
# song_df.printSchema()
# song_df.limit(5).toPandas()

# %%
sc = spark.sparkContext
rdd = sc.textFile(input_data + 'song_data/A/A/*').map(lambda x: json.loads(x))
song_df = rdd.map(lambda items: Row(**items)).toDF()
song_df.printSchema()
song_df.limit(3).toPandas()
song_df.cache()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: double (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)
#             artist_id  artist_latitude    artist_location  artist_longitude  \
# 0  ARJNIUY12298900C91              NaN                                  NaN
# 1  AR73AIO1187B9AD57B         37.77916  San Francisco, CA        -122.42005
# 2  ARMJAGH1187FB546F3         35.14968        Memphis, TN         -90.04892
#
#          artist_name   duration  num_songs             song_id  \
# 0       Adelitas Way  213.94240          1  SOBLFFE12AF72AA5BA
# 1  Western Addiction  118.07302          1  SOQPWCR12A6D4FB2A3
# 2       The Box Tops  148.03546          1  SOCIWDW12A8C13D406
#
#                               title  year
# 0                            Scream  2009
# 1  A Poor Recipe For Civic Cohesion  2005
# 2                         Soul Deep  1969

# %%
songs_table = song_df.select('song_id', 'title', 'artist_id', 'year', 'duration')
artists_table = song_df.select('artist_id', 
                               col('artist_name').alias('name'), 
                               col('artist_location').alias('location'), 
                               col('artist_latitude').alias('latitude'), 
                               col('artist_longitude').alias('longitude')).dropDuplicates()

# %%
songs_table.show(3)
# Out:
# +------------------+--------------------+------------------+----+---------+
# |           song_id|               title|         artist_id|year| duration|
# +------------------+--------------------+------------------+----+---------+
# |SOBLFFE12AF72AA5BA|              Scream|ARJNIUY12298900C91|2009| 213.9424|
# |SOQPWCR12A6D4FB2A3|A Poor Recipe For...|AR73AIO1187B9AD57B|2005|118.07302|
# |SOCIWDW12A8C13D406|           Soul Deep|ARMJAGH1187FB546F3|1969|148.03546|
# +------------------+--------------------+------------------+----+---------+
# only showing top 3 rows

# %%
artists_table.show(3)

# %%
log_df = log_df.filter(col('page') == 'NextSong')

# %%
log_df.limit(3).toPandas()
# Out:
#        artist       auth firstName gender  itemInSession lastName     length  \
# 0     Des'ree  Logged In    Kaylee      F              1  Summers  246.30812
# 1     Mr Oizo  Logged In    Kaylee      F              3  Summers  144.03873
# 2  Tamba Trio  Logged In    Kaylee      F              4  Summers  177.18812
#
#   level                     location method      page  registration  \
# 0  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1.540345e+12
# 1  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1.540345e+12
# 2  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1.540345e+12
#
#    sessionId                          song  status             ts  \
# 0        139                  You Gotta Be     200  1541106106796
# 1        139                       Flat 55     200  1541106352796
# 2        139  Quem Quiser Encontrar O Amor     200  1541106496796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      8
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      8
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      8

# %%
users_table = log_df.select(col('userId').alias('user_id'), 
                            col('firstName').alias('first_name'),
                            col('lastName').alias('last_name'),
                            'gender',
                            'level')

# %%
get_timestamp = udf(lambda ts: str(int(ts)//1000))
log_df = log_df.withColumn('timestamp', get_timestamp('ts'))

# %%
get_datetime = udf(lambda timestamp: str(datetime.fromtimestamp(int(timestamp))))
log_df = log_df.withColumn('datetime', get_datetime('timestamp'))

# %%
log_df.limit(5).toPandas()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0            Des'ree  Logged In    Kaylee      F              1  Summers
# 1            Mr Oizo  Logged In    Kaylee      F              3  Summers
# 2         Tamba Trio  Logged In    Kaylee      F              4  Summers
# 3     The Mars Volta  Logged In    Kaylee      F              5  Summers
# 4  Infected Mushroom  Logged In    Kaylee      F              6  Summers
#
#       length level                     location method  ... sessionId  \
# 0  246.30812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  ...       139
# 1  144.03873  free  Phoenix-Mesa-Scottsdale, AZ    PUT  ...       139
# 2  177.18812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  ...       139
# 3  380.42077  free  Phoenix-Mesa-Scottsdale, AZ    PUT  ...       139
# 4  440.26730  free  Phoenix-Mesa-Scottsdale, AZ    PUT  ...       139
#
#                            song  status             ts  \
# 0                  You Gotta Be     200  1541106106796
# 1                       Flat 55     200  1541106352796
# 2  Quem Quiser Encontrar O Amor     200  1541106496796
# 3                     Eriatarka     200  1541106673796
# 4               Becoming Insane     200  1541107053796
#
#                                            userAgent  userId  timestampe  \
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8  1541106106
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8  1541106352
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8  1541106496
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8  1541106673
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8  1541107053
#
#     timestamp             datetime hour
# 0  1541106106  2018-11-01 14:01:46   14
# 1  1541106352  2018-11-01 14:05:52   14
# 2  1541106496  2018-11-01 14:08:16   14
# 3  1541106673  2018-11-01 14:11:13   14
# 4  1541107053  2018-11-01 14:17:33   14
#
# [5 rows x 22 columns]

# %%
time_table = log_df.select(col('ts').alias('start_time'), 'datetime')\
    .withColumn('hour', hour('datetime'))\
    .withColumn('day', dayofmonth('datetime'))\
    .withColumn('week', weekofyear('datetime'))\
    .withColumn('month', month('datetime'))\
    .withColumn('year', year('datetime'))\
    .withColumn('weekday', dayofweek('datetime'))\
    .drop('datetime')

# %%
time_table.show(5)
# Out:
# +-------------+----+---+----+-----+----+-------+
# |   start_time|hour|day|week|month|year|weekday|
# +-------------+----+---+----+-----+----+-------+
# |1541106106796|  14|  1|  44|   11|2018|      5|
# |1541106352796|  14|  1|  44|   11|2018|      5|
# |1541106496796|  14|  1|  44|   11|2018|      5|
# |1541106673796|  14|  1|  44|   11|2018|      5|
# |1541107053796|  14|  1|  44|   11|2018|      5|
# +-------------+----+---+----+-----+----+-------+
# only showing top 5 rows

# %%
join_df = log_df.join(song_df, col('artist') == col('artist_name'))

# %%
# join_df.select("*")\
#     .withColumn("songplay_id", row_number().over(Window.orderBy(monotonically_increasing_id())) - 1)\
#     .limit(10).toPandas()

# %%
songplays_table = join_df.withColumn("songplay_id", monotonically_increasing_id())\
    .select('songplay_id',
            col('datetime').alias('start_time'),
            col('userId').alias('user_id'),
            col('level').alias('level'),
            col('song_id').alias('song_id'),
            col('artist_id').alias('artist_id'),
            col('sessionId').alias('session_id'),
            col('location').alias('location'),
            col('userAgent').alias('user_agent'),
            year('datetime').alias('year'),
            month('datetime').alias('month'))
